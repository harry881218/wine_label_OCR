# %%
import easyocr
from PIL import Image

# %%
reader = easyocr.Reader(['ch_sim','en']) # this needs to run only once to load the model into memory
result = reader.readtext('../EasyOCR/examples/chinese.jpg')
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
print(result)
# Out:
# [([[86, 80], [134, 80], [134, 128], [86, 128]], '西', 0.6629598563364745), ([[189, 75], [469, 75], [469, 165], [189, 165]], '愚园路', 0.9619015323198089), ([[517, 81], [565, 81], [565, 123], [517, 123]], '东', 0.9935730580773452), ([[78, 126], [136, 126], [136, 156], [78, 156]], '315', 0.9999927733243802), ([[514, 126], [574, 126], [574, 156], [514, 156]], '309', 0.9999620084121807), ([[79, 173], [125, 173], [125, 213], [79, 213]], 'W', 0.23369882903558903), ([[226, 170], [414, 170], [414, 220], [226, 220]], 'Yuyuan Rd。', 0.8949639433306373), ([[529, 173], [569, 173], [569, 213], [529, 213]], 'E', 0.5179030290151445)]

# %%
img = Image.open('trainer/all_data/filtered/valid/102786_jpg.rf.af50c464ff2e0234ae83f6bf9b3cccc6.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>

# %%
reader_1 = easyocr.Reader(['en'], recog_network='v1_best_accuracy')
result_1 = reader_1.readtext('trainer/all_data/filtered/valid/102786_jpg.rf.af50c464ff2e0234ae83f6bf9b3cccc6.jpg', detail=0)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
print(result_1)
# Out:
# ['INSOGLIO', 'del einghiale', 'Campo di Sasso', 'Bibbona', '2007', 'TOSCANA', '"Trhraxton', 'Lcotfrae']

# %%
reader_2 = easyocr.Reader(['en'], recog_network='v2_best_accuracy')
result_2 = reader_2.readtext('trainer/all_data/filtered/valid/102786_jpg.rf.af50c464ff2e0234ae83f6bf9b3cccc6.jpg', detail=0)
print(result_2)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['INSOGLIO', 'del einghiale', 'Campo di Sasso', 'Bibbona', '2007', 'TOSCANA', '"Trhraxton', 'Laotfrae']

# %%
reader_3 = easyocr.Reader(['en'], recog_network='v3_best_accuracy')
result_3 = reader_3.readtext('trainer/all_data/filtered/valid/102786_jpg.rf.af50c464ff2e0234ae83f6bf9b3cccc6.jpg', detail=0)
print(result_3)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['INSOGLIO', 'del einghiale', 'Campo di Sasso', 'Bibbona', '2007', 'TOSCANA', '"Trhraxton', 'Lcotfraee']

# %%
reader_4 = easyocr.Reader(['en'], recog_network='v4_best_accuracy')
result_4 = reader_4.readtext('trainer/all_data/filtered/valid/102786_jpg.rf.af50c464ff2e0234ae83f6bf9b3cccc6.jpg', detail=0)
print(result_4)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['INSOGLIO', 'del einghiale', 'Campo di Sasso', 'Bibbona', '2007', 'TOSCANA', '"Trhraxtor', 'Lcotfrae']

# %%
from os import walk
import random

# %%
valid_dir = 'trainer/all_data/filtered/valid/'
imgnames = next(walk(valid_dir), (None, None, []))[2]
sample_imgs = random.sample(imgnames, 5)
for img in sample_imgs:
    img_i = Image.open(valid_dir + img)
    display(img_i)
    output_1 = reader_1.readtext(valid_dir + img, detail=0)
    output_2 = reader_2.readtext(valid_dir + img, detail=0)
    output_3 = reader_3.readtext(valid_dir + img, detail=0)
    output_4 = reader_4.readtext(valid_dir + img, detail=0)
    print(output_1)
    print(output_2)
    print(output_2)
    print(output_4)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
# ['ACINUM', 'PROSECC0', 'E X T R ^', 'D R !', 'denoinatione', 'Okicint', 'P#OTFT']
# ['ACINUM', 'PROSECC0', 'E X T R ^', 'D R !', 'denoinatione', 'Okicint', 'P#OTFT']
# ['ACINUM', 'PROSECC0', 'E X T R ^', 'D R !', 'denoinatione', 'Okicint', 'P#OTFT']
# ['ACINUM', 'PROSECCO', 'E X T R ^', 'D R !', 'denoinaione', 'OkIcINF', 'P#OTFT']
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
# ['39', 'LA MONTESA', 'RI0.A', '~0/ 0 0"', '0 0|u 4 6', 'monma', '0e4in', '1', 'PALACIOS', 'REK ONOC', 'ALFaro']
# ['89', 'LA MONTESA', 'RI0.A', '0/ 0 04', '0 0|u 4 6', 'monmn', '0e4in', '1', 'PALACIOS', 'REX ONOC', 'ALFaro']
# ['89', 'LA MONTESA', 'RI0.A', '0/ 0 04', '0 0|u 4 6', 'monmn', '0e4in', '1', 'PALACIOS', 'REX ONOC', 'ALFaro']
# ['89', 'LA MONTESA', 'RTOA', 'F', '0M(u 4 6', 'monmn', 'ean', '1', 'PALACIOS', 'REKONDC', 'ALFARO']
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
# ['AAISON', "L'", 'ENVOYE', '9', '2', '20', 'TWo MESSENGERS', 'MILLAMETTE VALLEY']
# ['AAISON', "L'", 'ENVOYE', '9', '2', '20', 'TWo MESSENGERS', 'MILLAMETTE VALLEY']
# ['AAISON', "L'", 'ENVOYE', '9', '2', '20', 'TWo MESSENGERS', 'MILLAMETTE VALLEY']
# ['MAISON', "L'", 'ENVOYE', '9', '2', '20', 'TWO MESSENGERS', 'MILLAMETTE VALLEY']
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
# ['@aelumn', 'RU S SI4 N', 'KIVE R', 'VALLEY', 'C HA RD 0 NNAY', '2 010', 'CELLALD i4 The', 'TMWml', 'ian Rivem VILLET', 'Jnnoy', 'Coment', 'Ceiroraia', 'm Im;', 'BowDo', 'Munlldon', '021243']
# ['@aelumn', 'RU S SI4 N', 'KIVE R', 'VALLEY', 'C HA RD 0 NNAY', '2 010', 'a', 'TMWml', 'ian Rivem VILLEt', 'Jnnoy', 'Coment', 'Cairorana', 'm Im;', 'BoWDco', 'Munlldon', '021243']
# ['@aelumn', 'RU S SI4 N', 'KIVE R', 'VALLEY', 'C HA RD 0 NNAY', '2 010', 'a', 'TMWml', 'ian Rivem VILLEt', 'Jnnoy', 'Coment', 'Cairorana', 'm Im;', 'BoWDco', 'Munlldon', '021243']
# ['@aelumn', 'RU S STAN', 'KIVER', 'VALLEY', 'C HA RD O NNAY', '2010', 'a', 'TMml}', 'IaN Rivem VILLET', 'Jnnoy', 'Coet', 'Ceiirorana', 'MIm;', 'BoWDD', 'S', '02243']
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
# ['ABADiA DE', 'SAN CAMPIO', 'ALBarINo', '@L.O. AHAS BAIXAS', "'2019"]
# ['ABADiA DE', 'SAN CAMPIO', 'ALBarINo', '@.0. AHAS BAIXAS', "'2019"]
# ['ABADiA DE', 'SAN CAMPIO', 'ALBarINo', '@.0. AHAS BAIXAS', "'2019"]
# ['ABADIA DE', 'SAN CAMPIO', 'ALBARINO', '@L.O AHAS BAIXAS', "'2019"]

# %%
valid_dir = 'trainer/all_data/filtered/valid/'
imgnames = next(walk(valid_dir), (None, None, []))[2]
sample_imgs = random.sample(imgnames, 5)
for img in sample_imgs:
    img_i = Image.open(valid_dir + img)
    display(img_i)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=32x13>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>
